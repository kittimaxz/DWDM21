# %% [markdown]
# <a href="https://colab.research.google.com/github/kittimaxz/DWDM21/blob/main/survey_(1_07_23_1_09_23).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # import ฟังก์ชัน pandasimport pandas as pd # import ฟังก์ชัน pandas

# %%
from google.colab import drive # เชื่อม drive ของเรา ถ้าเชื่อมสำเร็จจะขึ้นคำว่า Mounted at /content/drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os # จัดการเกี่ยวกับไฟล์ต่างๆ ในโฟล์เดอร์

# %%
path = '/content/drive/My Drive'

# %%
data_file_path = os.path.join(path,'survey (1.07.23-1.09.23).xlsx') # เอาที่อยู่ของไฟล์เชื่อมกับที่อยู่ของไฟล์เรา
data_file = pd.read_excel(data_file_path)

# %%
data_file
# Out:
#          # 1.1 TH Code     Level                 ชื่อ-นามสกุล  เพศ Num  \
# 0        1    TH519755   DIAMOND             คัทรียา จันทะพรม      0.0
# 1        2    TH812865  PLATINUM            Chongchai Kobkaew      0.0
# 2        3    TH123750   DIAMOND                นันทนา กิมเฮง      2.0
# 3        4    TH362068   DIAMOND                        รัตนา      2.0
# 4        5    TH583887   DIAMOND             ชมพูนุท ยังปรีดา      0.0
# ...    ...         ...       ...                          ...      ...
# 1297  1298    TH116852      KING  สุทธิพงษ์ หงษ์ยิ้ม หงษ์ยิ้ม      1.0
# 1298  1299    TH078461   DIAMOND             TH078461 พัชริดา      2.0
# 1299  1300    TH778556  PLATINUM           อินทัช ลีลาศรีสง่า      0.0
# 1300  1301    TH877063  Platinum                          NaN      NaN
# 1301  1302    TH703489  PLATINUM       SansernPornwatthanawet      0.0
#
#           เพศ    วัน/เดือน/ปี เกิด เบอร์โทรศัพท์  \
# 0     ไม่ทราบ  0000-00-00 00:00:00    66-8209231
# ...

# %%
data = data_file[['1.1 TH Code','Level','1.15 ผู้ให้บริการลำดับที่ 1','1.15 ข้อดีของผู้ให้บริการลำดับที่ 1','1.15 ผู้ให้บริการลำดับที่ 2','1.15 ข้อดีของผู้ให้บริการลำดับที่ 2','1.15 ผู้ให้บริการลำดับที่ 3','1.15 ข้อดีของผู้ให้บริการลำดับที่ 3','2.4 ข้อเสนอแนะสำหรับการปรับปรุง Application ของ VCANBUY']]
data.head(10)
# Out:
#   1.1 TH Code     Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 0    TH519755   DIAMOND                         NaN
# 1    TH812865  PLATINUM                         NaN
# 2    TH123750   DIAMOND                         NaN
# 3    TH362068   DIAMOND                         NaN
# 4    TH583887   DIAMOND                         NaN
# 5    TH158239       EMP                         NaN
# 6     TH11341   DIAMOND                         NaN
# 7    TH781932  PLATINUM                         NaN
# 8    TH069969      KING                      shopee
# 9     TH17836       EMP                         NaN
#
#   1.15 ข้อดีของผู้ให้บริการลำดับที่ 1 1.15 ผู้ให้บริการลำดับที่ 2  \
# 0                                 NaN                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# ...

# %% [markdown]
# # ***1.15 ผู้ให้บริการลำดับที่ 1***

# %%
set(data['1.15 ผู้ให้บริการลำดับที่ 1']) # ดูว่า 1.15 ผู้ให้บริการลำดับที่ 1 เก็บค่าอะไรไว้บ้าง
# Out:
# {'-',
#  '--',
#  '.',
#  '...',
#  1668,
#  1688,
#  'AAA',
#  'ALAGENT 1688',
#  'ARIBABA',
#  'ARiYAYA',
#  'AliExpress',
#  'Ariyaya',
#  'BD CARGO',
#  'BD-Cargo express',
#  'BTC คาร์โก้',
#  'Baobaocargo',
#  'Best',
#  'CTW',
#  'CTW 2U',
#  'CTW cargo',
#  'CTW2U',
#  'CVT',
#  'Ctw cargo',
#  'Fastship',
#  'Fat',
#  'GetTaobao',
#  'JMT',
#  'JPM Shipping',
#  'Jmfcargo',
#  'KA Express',
#  'KSF shipping',
#  'Kerry',
#  'LAZADA-TAOBAO',
#  'Lazada',
#  'Like order',
#  'Momo',
#  'Momo cargo',
#  'NEXT Logistic',
#  'P.S. Sport cargo ยกให้เลย',
#  'PS Sport Cargo',
#  'Resell ใน IG',
#  'Shein',
#  'Ship2you',
#  'Shipify',
#  'Shopee',
#  'Shopee express',
#  'Shoppee',
#  'Shoppy',
#  'TCAT',
#  'TH',
#  'TTP',
#  'TTP Cargo',
#  'TTPcargo',
#  'Taobao',
#  'Taobaoland',
#  'Tcat',
#  'Tcat cargo',
#  'Tcatbuy',
#  'Tcatcargo',
#  'Thailoois',
#  'The Bestcargo',
#  'The best cargo',
#  'The bestcargo',
#  'Tumdee',
#  'Uneed',
#  'VCANBUY',
#  'VCANBUY เท่านั้น',
# ...

# %%
data['1.15 ผู้ให้บริการลำดับที่ 1'].count()
# Out:
# 375

# %%
data[data['1.15 ผู้ให้บริการลำดับที่ 1'] == 'ฟ'].head() # Fat,แสง,otc ไม่แน่ใจคืออะไร
# Out:
#     1.1 TH Code     Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 364    TH583846  PLATINUM                           ฟ
#
#                    1.15 ข้อดีของผู้ให้บริการลำดับที่ 1  \
# 364  ค่าขนส่งใน เรทที่ถูก เทียบได้กับของ vcanbuy ลู...
#
#     1.15 ผู้ให้บริการลำดับที่ 2 1.15 ข้อดีของผู้ให้บริการลำดับที่ 2  \
# 364                         NaN                                 NaN
#
#     1.15 ผู้ให้บริการลำดับที่ 3 1.15 ข้อดีของผู้ให้บริการลำดับที่ 3  \
# 364                         NaN                                 NaN
#
#     2.4 ข้อเสนอแนะสำหรับการปรับปรุง Application ของ VCANBUY
# 364                                                NaN

# %%
data['1.15 ผู้ให้บริการลำดับที่ 1'].replace({'1668':'1688',
                                   'ALAGENT 1688':'1688',
                                   'ARIBABA':'Alibaba',
                                   'ARiYAYA':'Ariyaya',
                                   'BD CARGO':'BD Cargo',
                                   'BD-Cargo express':'BD Cargo',
                                   'BTC คาร์โก้':'BTC Cargo',
                                   'Best':'Best Express',
                                   'CTW':'CTW Cargo',
                                   'CTW 2U':'CTW2U',
                                   'CTW cargo':'CTW Cargo',
                                   'CVT':'CVT Cargo',
                                   'Ctw cargo':'CTW Cargo',
                                   'Fastship':'FastShip',
                                   'JMT':'JMT Transport',
                                   'Jmfcargo':'JMF Cargo',
                                   'KSF shipping':'KSF Shipping',
                                   'Kerry':'Kerry Express',
                                   'LAZADA-TAOBAO':'Lazada',
                                   'Like order':'Like Order Cargo',
                                   'Momo':'Momo Cargo (Ninja Cargo)',
                                   'Momo cargo':'Momo Cargo (Ninja Cargo)',
                                   'NEXT Logistic':'NEXT Logistics',
                                   'P.S. Sport cargo ยกให้เลย':'P.S. Sport Cargo',
                                   'P.S. Sport cargo':'P.S. Sport Cargo',
                                   'PS Sport Cargo':'P.S. Sport Cargo',
                                   'Resell ใน IG':'Resell',
                                   'Shein':'SHEIN',
                                   'Ship2you':'Ship2U Cargo',
                                   'Shoppee':'Shopee',
                                   'Shoppee express':'Shopee',
                                   'Shopee express':'Shopee',
                                   'Shoppy':'Shopee',
                                   'TCAT':'Tcat Cargo',
                                   'TTP':'TTP Cargo',
                                   'TTPcargo':'TTP Cargo',
                                   'Tcat':'Tcat Cargo',
                                   'Tcat cargo':'Tcat Cargo',
                                   'Tcatbuy':'Tcatbuy Preorder',
                                   'Tcatcargo':'Tcat Cargo',
                                   'Thailoois':'Thailoois Logistics',
                                   'The Bestcargo':'The Best Cargo',
                                   'The best cargo':'The Best Cargo',
                                   'The bestcargo':'The Best Cargo',
                                   'Tumdee':'Tumdee Thai Logistics',
                                   'Uneed':'Uneed Cargo',
                                   'WESHOPCHINA':'Weshopchina',
                                   'YD':'YD Cargo',
                                   'YD cargo':'YD Cargo',
                                   'alibaba':'Alibaba',
                                   'alibabaeasy':'Alibabaeasy',
                                   'alieasyeasy':'Alieasyeasy',
                                   'aliexpress':'AliExpress',
                                   'baobao':'Baobaocargo',
                                   'best express':'Best Express',
                                   'caineo':'Cainiao',
                                   'cainiao':'Cainiao',
                                   'chinathai':'Chinathai Cargo',
                                   'cns':'CNS Cargo',
                                   'ctw cargo':'CTW Cargo',
                                   'fastrade':'Fasttrade',
                                   'fasttade':'Fasttrade',
                                   'gettaobao':'Gettaobao',
                                   'iazada กรณีส่งจากต่างประเทศ':'Lazada',
                                   'lasada':'Lazada',
                                   'lazada':'Lazada',
                                   'momo':'Momo Cargo (Ninja Cargo)',
                                   'momo cargo':'Momo Cargo (Ninja Cargo)',
                                   'momocargo':'Momo Cargo (Ninja Cargo)',
                                   'plm-cargo':'PLM Cargo',
                                   'shein':'SHEIN',
                                   'shopatthai':'Shopatthai',
                                   'shopee':'Shopee',
                                   'shoppee':'Shopee',
                                   'taobao':'Taobao',
                                   'taobao2you':'Taobao2you',
                                   'taobaocargo':'Taobao Cargo',
                                   'tcat mall':'Tcatmall',
                                   'tcatbuy':'Tcatbuy Preorder',
                                   'tcatmall':'Tcatmall',
                                   'the best cargo':'The Best Cargo',
                                   'ttp cargo':'TTP Cargo',
                                   'website1688':'1688',
                                   'weshopchina':'Weshopchina',
                                   'weshopchina.com':'Weshopchina',
                                   'ydcargo':'YD Cargo',
                                   'ขอไม่ระบุชื่อ (ทางเราสั่งผลิตสินค้าตรงกับโรงงานใน Alibaba คุยเอง ชำระเงินเอง ให้ชิปปิ้งเป็นโกดังรับสินค้า ตรวจสอบ และนำส่งเข้าไทยมาถึงออฟฟิศในกรุงเทพฯ)':'ไม่ประสงค์ระบุชื่อ',
                                   'คนรู่้จัก':'ผ่านตัวแทน',
                                   'ช็อปปี้':'Shopee',
                                   'ช้อปปี้':'Shopee',
                                   'ตัวแทนนำเข้าสินค้าจากจีนมาไทย':'ผ่านตัวแทน',
                                   'ติ๊กต๊อก':'TikTok',
                                   'ทำดี':'Tumdee Thai Logistics',
                                   'นินจาคาโก้':'Momo Cargo (Ninja Cargo)',
                                   'คุณอี๋':'ผ่านตัวแทน',
                                   'นิ่มเอ็กเพรส':'Nim Express',
                                   'ปณ ไทย ems':'Thailand Post',
                                   'ผู้ประการ รายอื่น ทั่วไป':'ผ่านตัวแทน',
                                   'ผ่านนายหน้าตัวกลาง ที่มีประสบการณ์โดยไม่รู้ว่าเค้าใช้ขนส่งเจ้าไหน แต่ได้เรทราคาที่ถูกกว่ามาก':'ผ่านตัวแทน',
                                   'ฝากคนรู้จักซื้อ':'ผ่านตัวแทน',
                                   'ลาซาด้า':'Lazada',
                                   'ลาซ้าด้า':'Lazada',
                                   'สั่งจากตัวแทนรับสั่งที่ทางvcanbuyไม่มี':'ผ่านตัวแทน',
                                   'สั่งตรง':'สั่งเองโดยตรง',
                                   'สั่งตรงจาก Taobao':'Taobao',
                                   'สั่งผ่านแอพ':'Taobao',
                                   'อาลีบาบาอีซี่':'Alibabaeasy',
                                   'เถาเปา':'Taobao',
                                   'โอเตะ':'OTE',
                                   'ไทยลูอิส':'Thailoois Logistics',
                                   'ไทยลูอีส':'Thailoois Logistics',
                                   'ไปรษณีย์':'Thailand Post',
                                    '๊Uget':'Uget Shopping',
                                   'otc':'OTE',
                                   'ํYD cargo':'YD Cargo'}, inplace=True)
# Out:
# <ipython-input-11-dbdef74fea3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['1.15 ผู้ให้บริการลำดับที่ 1'].replace({'1668':'1688',

# %%
data.tail(10)
# Out:
#      1.1 TH Code     Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 1292    TH141912  PLATINUM                         NaN
# 1293    TH856900  Platinum                       SHEIN
# 1294    TH701124   DIAMOND                     Vcanbuy
# 1295    TH357166  PLATINUM                   TTP Cargo
# 1296    TH791169  PLATINUM                         NaN
# 1297    TH116852      KING                         NaN
# 1298    TH078461   DIAMOND                         NaN
# 1299    TH778556  PLATINUM                   TTP Cargo
# 1300    TH877063  Platinum                         NaN
# 1301    TH703489  PLATINUM                         NaN
#
#         1.15 ข้อดีของผู้ให้บริการลำดับที่ 1 1.15 ผู้ให้บริการลำดับที่ 2  \
# 1292                                    NaN                         NaN
# 1293                                ส่งเร็ว                         NaN
# 1294                            เป็นที่นิยม                         NaN
# ...

# %%
group_no1 = data.groupby('1.15 ผู้ให้บริการลำดับที่ 1').count().sort_values(by=['1.1 TH Code'],ascending=False)
group_no1.iloc[:,:1:]
# Out:
#                              1.1 TH Code
# 1.15 ผู้ให้บริการลำดับที่ 1
# Shopee                                65
# ไม่มี                                 48
# Lazada                                32
# -                                     31
# Vcanbuy                               11
# ...                                  ...
# Ship2U Cargo                           1
# Resell                                 1
# PLM Cargo                              1
# Nim Express                            1
# ไม่ได้ใช้ช่องทางอื่น                   1
#
# [108 rows x 1 columns]

# %%
data[data['1.15 ผู้ให้บริการลำดับที่ 1'] == 'Shopee']
# Out:
#      1.1 TH Code     Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 8       TH069969      KING                      Shopee
# 39      TH846175  PLATINUM                      Shopee
# 44      TH613705   DIAMOND                      Shopee
# 48      TH068385  PLATINUM                      Shopee
# 51      TH854367  Platinum                      Shopee
# ...          ...       ...                         ...
# 1153    TH478228   DIAMOND                      Shopee
# 1168    TH117908  PLATINUM                      Shopee
# 1191    TH873931  Platinum                      Shopee
# 1201    TH676619  PLATINUM                      Shopee
# 1210    TH128180  PLATINUM                      Shopee
#
#                     1.15 ข้อดีของผู้ให้บริการลำดับที่ 1  \
# 8                                                   NaN
# 39                                    ตรวจสอบสินค้าง่าย
# 44    มีระบบรองรับการจ่ายชำระค่าสินค้าหลายช่องทางและ...
# 48                         ชัดเจนราคาและค่าส่ง มีส่วนลด
# ...

# %%
#data['1.15 ผู้ให้บริการลำดับที่ 1'][1100]

# %% [markdown]
# # ***1.15 ผู้ให้บริการลำดับที่ 2***

# %%
set(data['1.15 ผู้ให้บริการลำดับที่ 2'])
# Out:
# {'-',
#  '.',
#  'AliExpress',
#  'Alibaba',
#  'Ariyaya',
#  'BD cargo',
#  'Cvt',
#  'DHL',
#  'GOPU',
#  'Hand Shipping',
#  'Iazada',
#  'Lazada',
#  'Nim',
#  'Ninjavan',
#  'SHIEN',
#  'Shopee',
#  'Shopee-เอเซียตะวันออกเฉียงไต้',
#  'Shoppee',
#  'TTP Cargo',
#  'Taobao2you',
#  'Tcatmall',
#  'Vcanbuy',
#  'aliexpress',
#  'ariyaya',
#  'facebook',
#  'instagram',
#  'lazada',
#  nan,
#  'ninjacargo',
#  'shopee',
#  'taobao',
#  'taobao2you',
#  'ttpcargo',
#  'vcanbuy',
#  'wecanbuy',
#  'ชีอิน',
#  'ช้อปปี้',
#  'นิ่ม express',
#  'ผู้ที่โฆษณาขายทางเฟสบุ๊ค',
#  'พ่อค้าคนกลาง',
#  'มีเจ้าหน้าที่ คอยติดตามตลอด สื่อสารสะดวก',
#  'ลาซาด้า',
#  'สั่งจากร้านรับพรีในเพจ',
#  'อเมซอน',
#  'เฟสบุค',
#  'เอกชน',
#  'ไม่มี',
#  'ไม่มี ใช้แต่vcanbuy',
#  'ไม่ระบุ',
#  '่่ช้อปปี้'}

# %%
data['1.15 ผู้ให้บริการลำดับที่ 2'].count()
# Out:
# 92

# %%
data[data['1.15 ผู้ให้บริการลำดับที่ 2'] == 'Aliexpress']
# Out:
# Empty DataFrame
# Columns: [1.1 TH Code, Level, 1.15 ผู้ให้บริการลำดับที่ 1, 1.15 ข้อดีของผู้ให้บริการลำดับที่ 1, 1.15 ผู้ให้บริการลำดับที่ 2, 1.15 ข้อดีของผู้ให้บริการลำดับที่ 2, 1.15 ผู้ให้บริการลำดับที่ 3, 1.15 ข้อดีของผู้ให้บริการลำดับที่ 3, 2.4 ข้อเสนอแนะสำหรับการปรับปรุง Application ของ VCANBUY]
# Index: []

# %%
data['1.15 ผู้ให้บริการลำดับที่ 2'].replace({'BD cargo':'BD Cargo',
                                   'Cvt':'CVT Cargo',
                                   'DHL':'DHL Express Thailand',
                                   'Iazada':'Lazada',
                                   'Nim':'NIM Express',
                                   'Ninjavan':'Ninja Van',
                                   'Shopee-เอเซียตะวันออกเฉียงไต้':'Shopee',
                                   'Shoppee':'Shopee',
                                   'aliexpress':'AliExpress',
                                   'ariyaya':'Ariyaya',
                                   'facebook':'Facebook',
                                   'instagram':'Instagram',
                                   'lazada':'Lazada',
                                   'ninjacargo':'Ninja Cargo',
                                   'ninja Cargo':'Ninja Cargo',
                                   'shopee':'Shopee',
                                   'taobao':'Taobao',
                                   'taobao2you':'Taobao2you',
                                   'ttpcargo':'TTP Cargo',
                                   'ชีอิน':'SHEIN',
                                   'ช้อปปี้':'Shopee',
                                   'นิ่ม express':'NIM Express',
                                   'ผู้ที่โฆษณาขายทางเฟสบุ๊ค':'ผ่านตัวแทน',
                                   'พ่อค้าคนกลาง':'ผ่านตัวกลาง',
                                   'ลาซาด้า':'Lazada',
                                   'สั่งจากร้านรับพรีในเพจ':'ผ่านตัวแทน',
                                   'อเมซอน':'Amazon',
                                   'เฟสบุค':'Facebook',
                                   'ช้อปปี้':'Shopee',
                                   '่่ช้อปปี้':'Shopee',
                                   'SHIEN':'SHEIN',
                                   'เอกชน':'ไม่ประสงค์ระบุชื่อ'}, inplace=True)
# Out:
# <ipython-input-19-b511dbc04ee0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['1.15 ผู้ให้บริการลำดับที่ 2'].replace({'BD cargo':'BD Cargo',

# %%
group_no2 = data.groupby('1.15 ผู้ให้บริการลำดับที่ 2').count().sort_values(by=['1.1 TH Code'],ascending=False)
group_no2.iloc[:,:1:]
# Out:
#                                           1.1 TH Code
# 1.15 ผู้ให้บริการลำดับที่ 2
# -                                                  19
# Shopee                                             18
# Lazada                                             10
# AliExpress                                          5
# ไม่มี                                               5
# Facebook                                            2
# SHEIN                                               2
# NIM Express                                         2
# Taobao2you                                          2
# TTP Cargo                                           2
# ผ่านตัวแทน                                          2
# Ariyaya                                             2
# wecanbuy                                            1
# vcanbuy                                             1
# มีเจ้าหน้าที่ คอยติดตามตลอด สื่อสารสะดวก            1
# ไม่ประสงค์ระบุชื่อ                                  1
# ...

# %% [markdown]
# # ***1.15 ผู้ให้บริการลำดับที่ 3***

# %%
set(data['1.15 ผู้ให้บริการลำดับที่ 3'])
# Out:
# {'-',
#  '.',
#  'Alibaba',
#  'Aliexpress',
#  'Ninja Shipping',
#  'Psport',
#  'Tiktok',
#  'Vcanbuy',
#  'ebay',
#  'ems',
#  'lazada',
#  nan,
#  'thaitopcargo',
#  'vcanbuy',
#  'ติ้กต้อก',
#  'สั่งจากในIG',
#  'ไม่มี',
#  'ไม่มีค่าส่งภายในประเทศ',
#  'ไใ่มี'}

# %%
data['1.15 ผู้ให้บริการลำดับที่ 3'].count()
# Out:
# 39

# %%
data[data['1.15 ผู้ให้บริการลำดับที่ 3'] == 'Psport']
# Out:
#     1.1 TH Code    Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 914     TH27852  EMPEROR                   JMF Cargo
#
#     1.15 ข้อดีของผู้ให้บริการลำดับที่ 1 1.15 ผู้ให้บริการลำดับที่ 2  \
# 914             ค่าส่งจีนไทยค่อนข้างถุก                   CVT Cargo
#
#     1.15 ข้อดีของผู้ให้บริการลำดับที่ 2 1.15 ผู้ให้บริการลำดับที่ 3  \
# 914                             เลสเงิน                      Psport
#
#     1.15 ข้อดีของผู้ให้บริการลำดับที่ 3  \
# 914                           ค่าส่งถุก
#
#     2.4 ข้อเสนอแนะสำหรับการปรับปรุง Application ของ VCANBUY
# 914                                      มันดูรกๆลายตา

# %%
data['1.15 ผู้ให้บริการลำดับที่ 3'].replace({'Aliexpress':'AliExpress',
                                   'Ninja Shipping':'Ninja Van',
                                   'Tiktok':'TikTok',
                                   'ebay':'eBay',
                                   'ems':'Thailand Post',
                                   'lazada':'Lazada',
                                   'thaitopcargo':'Thai Top Cargo',
                                   'ติ้กต้อก':'Tiktok',
                                   'สั่งจากในIG':'Instagram',
                                   'Psport':'P.S. Sport Cargo'}, inplace=True)
# Out:
# <ipython-input-24-216c515fd942>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['1.15 ผู้ให้บริการลำดับที่ 3'].replace({'Aliexpress':'AliExpress',

# %%
group_no3 = data.groupby('1.15 ผู้ให้บริการลำดับที่ 3').count().sort_values(by=['1.1 TH Code'],ascending=False)
group_no3.iloc[:,:1:]
# Out:
#                              1.1 TH Code
# 1.15 ผู้ให้บริการลำดับที่ 3
# -                                     18
# ไม่มี                                  3
# Alibaba                                2
# Vcanbuy                                2
# TikTok                                 1
# ไม่มีค่าส่งภายในประเทศ                 1
# vcanbuy                                1
# eBay                                   1
# Tiktok                                 1
# Thailand Post                          1
# .                                      1
# Thai Top Cargo                         1
# P.S. Sport Cargo                       1
# Ninja Van                              1
# Lazada                                 1
# Instagram                              1
# AliExpress                             1
# ไใ่มี                                  1

# %%
data.head(20)
# Out:
#    1.1 TH Code     Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 0     TH519755   DIAMOND                         NaN
# 1     TH812865  PLATINUM                         NaN
# 2     TH123750   DIAMOND                         NaN
# 3     TH362068   DIAMOND                         NaN
# 4     TH583887   DIAMOND                         NaN
# 5     TH158239       EMP                         NaN
# 6      TH11341   DIAMOND                         NaN
# 7     TH781932  PLATINUM                         NaN
# 8     TH069969      KING                      Shopee
# 9      TH17836       EMP                         NaN
# 10    TH572878  PLATINUM                         NaN
# 11    TH398422      KING                         NaN
# 12    TH682522  PLATINUM                         NaN
# 13    TH786734  PLATINUM                      Taobao
# 14    TH144908   DIAMOND                         NaN
# 15    TH541334   DIAMOND                         NaN
# 16     TH27383       EMP                         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1302 entries, 0 to 1301
# Data columns (total 9 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   1.1 TH Code                                              1302 non-null   object
#  1   Level                                                    1302 non-null   object
#  2   1.15 ผู้ให้บริการลำดับที่ 1                              375 non-null    object
#  3   1.15 ข้อดีของผู้ให้บริการลำดับที่ 1                      225 non-null    object
#  4   1.15 ผู้ให้บริการลำดับที่ 2                              92 non-null     object
#  5   1.15 ข้อดีของผู้ให้บริการลำดับที่ 2                      75 non-null     object
#  6   1.15 ผู้ให้บริการลำดับที่ 3                              39 non-null     object
#  7   1.15 ข้อดีของผู้ให้บริการลำดับที่ 3                      36 non-null     object
# ...

# %% [markdown]
# # ***1.15 ข้อดีของผู้ให้บริการลำดับที่ 1***

# %%
set(data['1.15 ข้อดีของผู้ให้บริการลำดับที่ 1'])
# Out:
# {'-',
#  '.',
#  '...',
#  'AP Cargo',
#  'AliExpress',
#  'CMpanda',
#  'J',
#  'Lazada',
#  'TCAT',
#  'Taobao',
#  'Tiktok',
#  'lazada',
#  nan,
#  'ninja',
#  'taobao2you',
#  'update สถานะได้ชัดเจน',
#  'vcanbuy',
#  'we can buy',
#  'การชำระค่าสินค้าและขนส่งทำได้ง่าย มีคูปองส่วนลดค่าขนส่ง หรือฟรีค่าขนส่ง',
#  'การติดตามข้อมูลดี แจ้งสถานชัดเจน',
#  'การันตีคืนเงินถ้าสินค้าไม่ตรงปกหรือเสียหาย',
#  'ขนส่ง ราคาไม่แพง ค่าส่งจากจีน แล้วสามารถซื้อ ชิ้น 2 ชิ้นได้ บ้างร้าน',
#  'ขนส่งธูปเทียนได้ แต่มีเก็บปลายทางอีก ไม่จ่ายรวดเดียวจบเหมือนวีแคนบาย',
#  'ขนส่งรวดเร็วมาก ค่าส่งถูก',
#  'ของราคาถูก',
#  'ขอสงวนสิทธิ์ในการให้บริการของบริษัท',
#  'คนขาย อยู่ใน lazada',
#  'ความรวดเร็วในการส่งสินค้ามาถึงไทย',
#  'คัดลอกลิงค์ในแอพ Taobao',
#  'คุยโต้กันเอง มีระบบแจ้งเตือนผ่านไลน์',
#  'คุยได้และสั่งได้รวดเร็ว',
#  'คุ้นเคย',
#  'ค่าขนส่งจีน-ไทยถูก',
#  'ค่าขนส่งถูก',
#  'ค่าขนส่งถูก มีตัวการันตีว่าจะได้รับของจริงๆ ถ้าไม่ได้รับของเงินจะไม่โอนไปให้ร้านค้า',
#  'ค่าขนส่งถูก ราคาสินค้าถูก',
# ...

# %%
data['1.15 ข้อดีของผู้ให้บริการลำดับที่ 1'].count()
# Out:
# 225

# %% [markdown]
# ***ข้อมูลอยู่ผิดที่***
#
# 1100,72,1093,481,629,1194,125,677,294,855,1135,311,239,110,99,996,387
#
# ***ไม่ระบุ = ไม่ประสงค์ระบุชื่อ

# %%
data[data['1.15 ข้อดีของผู้ให้บริการลำดับที่ 1']=='พนักงานรับออเดอร์ติดต่อร้านค้าโดยตรงและเมื่อเกิดข้อผิดพลาดเช่นสินค้าส่งผิดชนิดพนักงานรับออเดอร์คนเดียวกันแก้ปัญหาให้กับลูกค้าทันทีซึ่งผิดกับvcanbuyต้องทำเรื่องเคลมกับพนักงานฝ่ายเคลม']
# Out:
#     1.1 TH Code Level 1.15 ผู้ให้บริการลำดับที่ 1  \
# 830    TH126164  KING                        1688
#
#                    1.15 ข้อดีของผู้ให้บริการลำดับที่ 1  \
# 830  พนักงานรับออเดอร์ติดต่อร้านค้าโดยตรงและเมื่อเก...
#
#     1.15 ผู้ให้บริการลำดับที่ 2 1.15 ข้อดีของผู้ให้บริการลำดับที่ 2  \
# 830                         NaN                                 NaN
#
#     1.15 ผู้ให้บริการลำดับที่ 3 1.15 ข้อดีของผู้ให้บริการลำดับที่ 3  \
# 830                         NaN                                 NaN
#
#     2.4 ข้อเสนอแนะสำหรับการปรับปรุง Application ของ VCANBUY
# 830                                                NaN

# %%
data['1.15 ผู้ให้บริการลำดับที่ 3'].replace({'update สถานะได้ชัดเจน':'แจ้งสถานะชัดเจน',
                                   'การชำระค่าสินค้าและขนส่งทำได้ง่าย มีคูปองส่วนลดค่าขนส่ง หรือฟรีค่าขนส่ง':'ชำระเงินง่าย,มีส่วนลดค่าขนส่ง,จัดส่งฟรี',
                                   'การติดตามข้อมูลดี แจ้งสถานชัดเจน':'การติดตามข้อมูลดี,แจ้งสถานะชัดเจน',
                                   'การันตีคืนเงินถ้าสินค้าไม่ตรงปกหรือเสียหาย':'ได้รับเงินคืนเมื่อสินค้าเสียหายหรือไม่มีคุณภาพ',
                                   'ขนส่ง ราคาไม่แพง ค่าส่งจากจีน แล้วสามารถซื้อ ชิ้น 2 ชิ้นได้ บ้างร้าน':'ค่าขนส่งถูก,สามารถซื้อสินค้าจำนวนน้อยชิ้นได้',
                                   'ขนส่งธูปเทียนได้ แต่มีเก็บปลายทางอีก ไม่จ่ายรวดเดียวจบเหมือนวีแคนบาย':'ขนส่งธูปเทียนได้,มีเก็บเงินปลายทาง',
                                   'ขนส่งรวดเร็วมาก ค่าส่งถูก':'จัดส่งรวดเร็ว,ค่าขนส่งถูก',
                                   'ของราคาถูก':'สินค้าราคาถูก',
                                   'คนขาย อยู่ใน lazada':'สามารถซื้อสินค้าด้วยตัวเองจากร้านค่าโดยตรง',
                                   'ความรวดเร็วในการส่งสินค้ามาถึงไทย':'จัดส่งรวดเร็ว',
                                   'คัดลอกลิงค์ในแอพ Taobao':'X',
                                   'คุยโต้กันเอง มีระบบแจ้งเตือนผ่านไลน์':'X,มีการแจ้งเตือนผ่านไลน์',
                                   'คุยได้และสั่งได้รวดเร็ว':'X,สั่งซื้อได้รวดเร็ว',
                                   'ค่าขนส่งถูก มีตัวการันตีว่าจะได้รับของจริงๆ ถ้าไม่ได้รับของเงินจะไม่โอนไปให้ร้านค้า':'ค่าขนส่งถูก,มั่นใจได้ว่าได้รับของจริง',
                                   'ค่าขนส่งถูก ราคาสินค้าถูก':'ค่าขนส่งถูก,สินค้าราคาถูก',
                                   'ค่าขนส่งถูก ได้รับสินค้าเร็ว':'ค่าขนส่งถูก,จัดส่งรวดเร็ว',
                                   'ค่าขนส่งราคาถูก':'ค่าขนส่งถูก',
                                   'ค่าขนส่งใน เรทที่ถูก เทียบได้กับของ vcanbuy ลูกค้าระดับที่ดีสุด':'ค่าขนส่งถูก',
                                   'ค่าส่งจีน-ไทย ถูกกว่า':'ค่าขนส่งจีน-ไทยถูก',
                                   'ค่าส่งจีน-ไทย ถูกกว่า การดูรายละเอียดสินค้าที่ส่งแล้วในเว็ปไซต์ดูง่ายกว่า':'ค่าขนส่งจีน-ไทยถูก,รายละเอียดสินค้าที่ส่งแล้วในเว็บไซต์ดูง่าย',
                                   'ค่าส่งจีนไทยค่อนข้างถุก':'ค่าขนส่งจีน-ไทยถูก',
                                   'ค่าส่งถูก':'ค่าขนส่งถูก',
                                   'ค่าส่งถูกเหมาจ่าย':'ค่าส่งแบบเหมาจ่ายถูก',
                                   'ค่าส่งไม่แพง ถูก มีโปร ส่งตรงมาจากจีนเลย':'ค่าขนส่งถูก,มีโปรโมชัน,ส่งตรงจากจีน',
                                   'ค้นหาสินค้าได้ง่าย ราคาถูก ส่วนลดเยอะ':'ค้นหาสินค้าง่าย,สินค้าราคาถูก,มีโปรโมชัน',
                                   'ง่าย รู้ราคาเลย ไม่จ่ายเพิ่ม':'การใช้งานง่าย,แสดงราคาชัดเจน,ไม่ต้องจ่ายเพิ่ม',
                                   'ง่าย เห็นสถานะอัพเดตแบบเรียลไทม์':'การใช้งานง่าย,สถานะอัพเดทแบบเรียลไทม์',
                                   'ง่ายในการสั่งซื้อ':'การใช้งานง่าย',
                                   'จัดการสั่งซื้อได้รวดเร็ว บางครั้งสินค้าเร่งด่วน ต้องการความรวดเร็ว':'สั่งซื้อได้รวดเร็ว',
                                   'จัดส่งฟรี-และราคาถูกกว่าใน Taobao ในหลายรายการ':'จัดส่งฟรี,สินค้าราคาถูก',
                                   'จัดส่งสินค้ารวดเร็ว ไม่คิดค่าส่งสินค้าในไทย ไม่มีค่าบริการอื่นๆ':'จัดส่งรวดเร็ว,ไม่คิดค่าส่งสินค้าในไทย,ไม่มีค่าบริการอื่นๆ',
                                   'จัดส่งเร็ว':'จัดส่งรวดเร็ว',
                                   'จุดรับสินค้าเยอะ เวปใช้ง่าย':'จุดรับสินค้าเยอะ,เว็บไซต์ใช้งานง่าย',
                                   'ชัดเจนราคาและค่าส่ง มีส่วนลด':'แสดงราคาชัดเจน,มีโปรโมชัน',
                                   'ซื้อจำนวนเยอะ อัตราค่าบริการถูกกว่า คุ้มกว่า':'อัตราค่าบริการถูกเมื่อซื้อสินค้าจำนวนมาก',
                                   'ตรวจนับสินค้าให้อย่างละเอียด ให้ตรงตามสเปคที่สั่ง ถ่ายภาพรายงานผลการตรวจเช็ค ถ่ายภาพสินค้าที่ได้รับจากโรงงานจีนให้ทางเราตรวจสอบในทุกจุดที่เน้นย้ำว่าต้องไม่พลาด และส่งมาถึงที่ออฟฟิศ ออกใบกำกับภาษีให้ได':'ตรวจสอบสินค้าละเอียด,X,ออกใบกำกับภาษีได้',
                                   'ตรวจสอบสถานะสินค้าได้ละเอียด':'ตรวจสอบสินค้าละเอียด',
                                   'ตัวเลือกเยอะ':'มีสินค้าให้้เลือกเยอะ',
                                   'ติดตามสถานะ และการขอคืนเงินและยกเลิกสินค้าทำได้อย่างรวดเร็ว':'ติดตามสถานะสินค้าสะดวก,สามารถขอคืนเงินและยกเลิกสินค้าได้รวดเร็ว',
                                   'ติดตามสินค้าได้สะดวก':'ติดตามสถานะสินค้าสะดวก',
                                   'ถูก':'ค่าขนส่งถูก',
                                   'ถูกมาก ไม่เสียค่าส่งทั้งในและนอกประเทศ ไม่มีค่าขิปปิ้ง ไม่ต้องรอพักสินค้า ระยะเวลาขนส่งโดยมากไม้เกิน 7 วัน แถมยังชำระปลายทางได้ คืนเงินคืนสินค้าง่าย':'ค่าขนส่งถูก,ไม่มีค่าขนส่งทั้งในและนอกประเทศ,ไม่ต้องรอพักสินค้า,จัดส่งรวดเร็ว,มีเก็บเงินปลายทาง,สามารถขอคืนเงินและยกเลิกสินค้าได้รวดเร็ว',
                                   'บริการดีมาก':'บริการดี',
                                   'บริการว่องไว เมื่อมีข้อสงสัยหรือมีปัญหา โทรประสานงานร้านค้าให้ทันทีแก้ปัญหารวดเร็ว':'บริการรวดเร็ว,X',
                                   'บางรายการ vcanbuy ไม่รับสั่ง':'X',
                                   'ประสานงานง่าย':'ประสานงานง่าย,มีเจ้าหน้าที่คอยติดตาม,จัดส่งรวดเร็ว,ไม่มีค่าขนส่งภายในประเทศ',
                                   'พนักงานรับออเดอร์ติดต่อร้านค้าโดยตรงและเมื่อเกิดข้อผิดพลาดเช่นสินค้าส่งผิดชนิดพนักงานรับออเดอร์คนเดียวกันแก้ปัญหาให้กับลูกค้าทันทีซึ่งผิดกับvcanbuyต้องทำเรื่องเคลมกับพนักงานฝ่ายเคลม':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':'',
                                   '':''}, inplace=True)
# Out:
# <ipython-input-71-e516d9cd82a0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['1.15 ผู้ให้บริการลำดับที่ 3'].replace({'update สถานะได้ชัดเจน':'แจ้งสถานะชัดเจน',

# %% [markdown]
# # ***Save Excel***

# %%
#data.to_excel('survey (1.07.23-1.09.23).xlsx', encoding='utf-8')
